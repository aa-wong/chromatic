# %%
# %pip install mido
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from midi2rgb import convert_midi_to_rgb

# %%
rgb_values = convert_midi_to_rgb("./song2.mid")

# %%
rgb_values
# Out:
# [(116, 0, 0),
#  (255, 122, 255),
#  (255, 255, 146),
#  (255, 116, 255),
#  (130, 0, 0),
#  (122, 0, 0),
#  (255, 146, 255),
#  (255, 255, 116),
#  (154, 0, 0),
#  (255, 255, 130),
#  (255, 255, 122),
#  (255, 255, 116),
#  (154, 0, 0),
#  (104, 0, 0),
#  (255, 130, 255),
#  (255, 255, 154),
#  (122, 0, 0),
#  (255, 255, 116),
#  (154, 0, 0),
#  (255, 164, 255),
#  (130, 0, 0),
#  (255, 255, 122),
#  (116, 0, 0),
#  (255, 154, 255),
#  (255, 255, 164),
#  (255, 255, 120),
#  (144, 0, 0),
#  (255, 158, 255),
#  (255, 255, 176),
#  (255, 255, 122),
#  (126, 0, 0),
#  (255, 154, 255),
#  (255, 255, 120),
#  (144, 0, 0),
#  (255, 158, 255),
#  (122, 0, 0),
#  (255, 134, 255),
#  (158, 0, 0),
#  (255, 126, 255),
#  (122, 0, 0),
#  (134, 0, 0),
#  (255, 158, 255),
#  (255, 122, 255),
#  (255, 255, 126),
#  (130, 0, 0),
#  (122, 0, 0),
#  (255, 136, 255),
#  (255, 255, 158),
#  (255, 130, 255),
#  (255, 255, 122),
#  (255, 255, 136),
#  (255, 255, 130),
#  (154, 0, 0),
#  (255, 255, 122),
# ...
